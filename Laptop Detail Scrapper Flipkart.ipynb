# %% [markdown]
# ## Scrapping the Data

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import mysql.connector
from datetime import date

# %% [markdown]
# WITH DUPLICATES
#
# url = 'https://www.flipkart.com/search?q=laptop&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off'
#
# laptop = []
#
# for i in range(1,100):
#     print(f"Scrapping Page {i}...")
#     response = requests.get(url + f"&page={i}")
#     soup = BeautifulSoup(response.text, 'html.parser')
#     product = soup.find_all("div", attrs={'class':'cPHDOP col-12-12'})
#
#     for i in product:
#
#         if i.find("a", {"class":"CGtC98"}):
#
#             link = 'https://www.flipkart.com' + i.find("a", {"class":"CGtC98"}).get("href")
#
#             name = i.find("div", attrs={'class':'KzDlHZ'}).text.strip() if i.find("div", attrs={'class':'KzDlHZ'}) else None
#
#             stars = i.find("div", attrs={'class':'XQDdHH'}).text.strip() if i.find("div", attrs={'class':'XQDdHH'}) else None
#
#             rating = int(i.find("span", attrs={'class':'Wphh3N'}).text.strip().replace("\xa0", " ").split(" ")[0].replace(",","")) if i.find("span", attrs={'class':'Wphh3N'}) else None
#
#             review = int(i.find("span", attrs={'class':'Wphh3N'}).text.strip().replace("\xa0", " ").split(" ")[3].replace(",","")) if i.find("span", attrs={'class':'Wphh3N'}) else None
#
#             disc_price = int(i.find("div", attrs={'class':'Nx9bqj _4b5DiR'}).text.strip().replace(",","").replace("₹","")) if i.find("div", attrs={'class':'Nx9bqj _4b5DiR'}) else None
#
#             orig_price = int(i.find("div", attrs={'class':'yRaY8j ZYYwLA'}).text.strip().replace(",","").replace("₹","")) if i.find("div", attrs={'class':'yRaY8j ZYYwLA'}) else None
#
#             discount = i.find("div", attrs={'class':'UkUFwK'}).text.strip().replace(" off","") if i.find("div", attrs={'class':'UkUFwK'}) else None
#
#             features = ", ".join([li.text.strip() for li in i.find("ul", attrs={"class":"G4BRas"}).find_all("li")]) if i.find("ul", attrs={"class":"G4BRas"}) else None
#
#             if name and stars and rating and review and disc_price and orig_price and dicount and features:
#
#                 continue
#
#             else:
#
#                 if link and name and disc_price:
#                     laptop.append({
#                         "Link": link,
#                         "Name": name,
#                         "Stars": stars,
#                         "Rating": rating,
#                         "Review": review,
#                         "Discounted_Price": disc_price,
#                         "Original_Price": orig_price,
#                         "Discount": discount,
#                         "Features": features,
#                         "date": date.today()
#                     })
#
#         else:
#             continue

# %%
## WITHOUT DUPLICATES

url = 'https://www.flipkart.com/search?q=laptop&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off'

laptop = []
seen_products = set()  # store unique product signature without link

for i in range(1, 100):
    print(f"Scraping Page {i}...")
    response = requests.get(url + f"&page={i}")
    soup = BeautifulSoup(response.text, 'html.parser')
    product = soup.find_all("div", attrs={'class': 'cPHDOP col-12-12'})
    
    for i in product:
        if i.find("a", {"class": "CGtC98"}):
            link = 'https://www.flipkart.com' + i.find("a", {"class": "CGtC98"}).get("href")
            
            name = i.find("div", attrs={'class': 'KzDlHZ'}).text.strip() if i.find("div", attrs={'class': 'KzDlHZ'}) else None
            
            stars = i.find("div", attrs={'class': 'XQDdHH'}).text.strip() if i.find("div", attrs={'class': 'XQDdHH'}) else None
            
            rating = int(i.find("span", attrs={'class': 'Wphh3N'}).text.strip().replace("\xa0", " ").split(" ")[0].replace(",", "")) if i.find("span", attrs={'class': 'Wphh3N'}) else None
            
            review = int(i.find("span", attrs={'class': 'Wphh3N'}).text.strip().replace("\xa0", " ").split(" ")[3].replace(",", "")) if i.find("span", attrs={'class': 'Wphh3N'}) else None
            
            disc_price = int(i.find("div", attrs={'class': 'Nx9bqj _4b5DiR'}).text.strip().replace(",", "").replace("₹", "")) if i.find("div", attrs={'class': 'Nx9bqj _4b5DiR'}) else None
            
            orig_price = int(i.find("div", attrs={'class': 'yRaY8j ZYYwLA'}).text.strip().replace(",", "").replace("₹", "")) if i.find("div", attrs={'class': 'yRaY8j ZYYwLA'}) else None
            
            discount = i.find("div", attrs={'class': 'UkUFwK'}).text.strip().replace(" off", "") if i.find("div", attrs={'class': 'UkUFwK'}) else None
            
            features = ", ".join([li.text.strip() for li in i.find("ul", attrs={"class": "G4BRas"}).find_all("li")]) if i.find("ul", attrs={"class": "G4BRas"}) else None

            # ✅ Required fields check
            if name and disc_price:
                # ✅ Create a unique signature (ignoring link)
                signature = (name, stars, rating, review, disc_price, orig_price, discount, features, date.today())
                
                if signature not in seen_products:  # prevent duplicates
                    seen_products.add(signature)
                    laptop.append({
                        "Link": link,
                        "Name": name,
                        "Stars": stars,
                        "Rating": rating,
                        "Review": review,
                        "Discounted_Price": disc_price,
                        "Original_Price": orig_price,
                        "Discount": discount,
                        "Features": features,
                        "date": date.today()
                    })

        else:
            continue
# Out:
# Scraping Page 1...
# Scraping Page 2...
# Scraping Page 3...
# Scraping Page 4...
# Scraping Page 5...
# Scraping Page 6...
# Scraping Page 7...
# Scraping Page 8...
# Scraping Page 9...
# Scraping Page 10...
# Scraping Page 11...
# Scraping Page 12...
# Scraping Page 13...
# Scraping Page 14...
# Scraping Page 15...
# Scraping Page 16...
# Scraping Page 17...
# Scraping Page 18...
# Scraping Page 19...
# Scraping Page 20...
# Scraping Page 21...
# Scraping Page 22...
# Scraping Page 23...
# Scraping Page 24...
# Scraping Page 25...
# Scraping Page 26...
# Scraping Page 27...
# Scraping Page 28...
# Scraping Page 29...
# Scraping Page 30...
# Scraping Page 31...
# Scraping Page 32...
# Scraping Page 33...
# Scraping Page 34...
# Scraping Page 35...
# Scraping Page 36...
# Scraping Page 37...
# Scraping Page 38...
# Scraping Page 39...
# Scraping Page 40...
# Scraping Page 41...
# Scraping Page 42...
# Scraping Page 43...
# Scraping Page 44...
# Scraping Page 45...
#
#                                                   Name Stars Rating Review  \
# 40   Lenovo 100e Chromebook Gen 4 MediaTek MediaTek...   3.8    519     38
# 91   Lenovo 100e Chromebook Gen 4 MediaTek MediaTek...   3.8    519     38
# 110  Lenovo 100e Chromebook Gen 4 MediaTek MediaTek...   3.8    519     38
# 160  Lenovo 100e Chromebook Gen 4 MediaTek MediaTek...   3.8    519     38
# 331  Lenovo 100e Chromebook Gen 4 MediaTek MediaTek...   3.8    519     38
# 413  Lenovo 100e Chromebook Gen 4 MediaTek MediaTek...   3.8    519     38
#
#      Discounted_Price Original_Price Discount  \
# 40               9998          37690      73%
# 91               9998          37690      73%
# 110              9998          37690      73%
# 160              9998          37690      73%
# 331              9998          37690      73%
# 413              9998          37690      73%
#
#                                               Features        date
# 40   MediaTek MediaTek Kompanio 528 Processor, 4 GB...  2025-09-27
# 91   MediaTek MediaTek Kompanio 528 Processor, 4 GB...  2025-09-27
# 110  MediaTek MediaTek Kompanio 528 Processor, 4 GB...  2025-09-27
# 160  MediaTek MediaTek Kompanio 528 Processor, 4 GB...  2025-09-27
# 331  MediaTek MediaTek Kompanio 528 Processor, 4 GB...  2025-09-27
# 413  MediaTek MediaTek Kompanio 528 Processor, 4 GB...  2025-09-27

# %%
laptop_details['Name'].nunique()
# Out:
# 539

# %%
x = laptop_details.iloc[40]['Link']

# %%
y = laptop_details.iloc[91]['Link']

# %% [markdown]
# ## Connecting to MYSQL

# %%
conn = mysql.connector.connect(
    host="localhost",
    user="root",
    password="MYSQLwb@1234",
    database="ecommerce_tracker"
)

cursor = conn.cursor()

for p in laptop:
    cursor.execute("""
        INSERT INTO products  (link, name, stars, number_of_rating, number_of_reviews, disc_price, orig_price, discount, features, scrape_date)
        VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
    """, (p["Link"],p["Name"],p["Stars"],p["Rating"],p["Review"],p["Discounted_Price"],p["Original_Price"],p["Discount"],p["Features"],p["date"]))

conn.commit()
cursor.close()
conn.close()

# %% [markdown]
# cursor.execute("DROP DATABASE IF EXISTS ecommerce_tracker")
# print("Database deleted successfully.")

# %%
laptop_details[laptop_details['Name'] == 'Acer Aspire 3 Intel Celeron Dual Core - (8 GB/256 GB SSD/Windows 11 Home) A311-45 Thin and Light Lapto...']
# Out:
#                                                   Link  \
# 213  https://www.flipkart.com/acer-aspire-3-intel-c...
# 252  https://www.flipkart.com/acer-aspire-3-intel-c...
#
#                                                   Name Stars Rating Review  \
# 213  Acer Aspire 3 Intel Celeron Dual Core - (8 GB/...   3.8   4560    420
# 252  Acer Aspire 3 Intel Celeron Dual Core - (8 GB/...   3.8   4560    420
#
#      Discounted_Price Original_Price Discount  \
# 213             15990          33399      52%
# 252             14990          33399      55%
#
#                                               Features        date
# 213  Intel Celeron Dual Core Processor, 8 GB DDR4 R...  2025-09-27
# 252  Intel Celeron Dual Core Processor, 8 GB DDR4 R...  2025-09-27
